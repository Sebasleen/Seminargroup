# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# <font size='4' face='Times new Roman'>
#     Dit worden de US Factors
#     <font>

# %%
Predictors = pd.read_csv('/Users/sebasleen/Seminargroup/US Factors/PredictorLSretWide.csv')
Predictors
# Out:
#            date        AM       AOP  AbnormalAccruals  Accruals  AccrualsBM  \
# 0    1963-07-31 -1.556432       NaN               NaN  0.986994         NaN
# 1    1963-08-30 -1.970184       NaN               NaN  2.906035         NaN
# 2    1963-09-30  0.417170       NaN               NaN  0.442702         NaN
# 3    1963-10-31  0.011723       NaN               NaN  1.926600         NaN
# 4    1963-11-29  0.546948       NaN               NaN  0.875763         NaN
# ..          ...       ...       ...               ...       ...         ...
# 673  2019-08-30 -3.477967  1.022858         -0.257870 -3.476139   -0.660723
# 674  2019-09-30  9.837431  1.138211         -1.426835 -0.879171    6.541993
# 675  2019-10-31 -0.619649 -0.268992          2.529173 -3.231276   -3.229082
# 676  2019-11-29 -5.184910 -1.554425          1.479976  4.253688   -5.467083
# 677  2019-12-31  1.037594  0.215954         -2.188127  0.662900   -4.129853
#
# ...
